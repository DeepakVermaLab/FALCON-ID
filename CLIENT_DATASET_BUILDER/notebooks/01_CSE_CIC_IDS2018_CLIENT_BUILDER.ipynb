# %%
# !pip install python-docx joblib --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.2 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/users/')
# Out:
# Mounted at /users/

# %%
import os
import json
import random
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt

from docx import Document
from datetime import datetime
import joblib

# %% [markdown]
# # CONFIGURATION

# %%
BASE_SAVE_DIR = "/users/"

DATASET_NAME = "CSE_CIC_IDS2018"
DATASET_DIR = os.path.join(BASE_SAVE_DIR, DATASET_NAME)

CLIENTS_DIR = os.path.join(DATASET_DIR, "clients_non_iid")
os.makedirs(CLIENTS_DIR, exist_ok=True)

# CSE-CIC-IDS2018: moderately large, many attack types
N_CLIENTS = 20          # you can tune this (e.g., 10 / 15 / 25)
DIRICHLET_ALPHA = 0.3   # lower => more non-iid label skew

print("DATASET_DIR :", DATASET_DIR)
print("CLIENTS_DIR :", CLIENTS_DIR)
print("N_CLIENTS   :", N_CLIENTS)
print("ALPHA       :", DIRICHLET_ALPHA)
# Out:
# DATASET_DIR : /users/
# CLIENTS_DIR : /users/
# N_CLIENTS   : 20
# ALPHA       : 0.3

# %% [markdown]
# # LOAD TRAIN LATENT FEATURES & LABELS

# %%
train_latent_path = os.path.join(DATASET_DIR, "train_latent.npy")
y_train_path      = os.path.join(DATASET_DIR, "y_train.npy")
label_encoder_path = os.path.join(DATASET_DIR, "label_encoder.pkl")

assert os.path.exists(train_latent_path), f"Missing: {train_latent_path}"
assert os.path.exists(y_train_path), f"Missing: {y_train_path}"
assert os.path.exists(label_encoder_path), f"Missing: {label_encoder_path}"

X_train = np.load(train_latent_path)
y_train = np.load(y_train_path)
label_encoder = joblib.load(label_encoder_path)

class_names = list(label_encoder.classes_)
num_classes = len(class_names)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("Total classes:", num_classes)
print("Sample class names:", class_names[:20])
if num_classes > 20:
    print(f"... and {num_classes - 20} more")
# Out:
# X_train shape: (6737603, 64)
# y_train shape: (6737603,)
# Total classes: 15
# Sample class names: ['Benign', 'Bot', 'Brute Force -Web', 'Brute Force -XSS', 'DDOS attack-HOIC', 'DDOS attack-LOIC-UDP', 'DDoS attacks-LOIC-HTTP', 'DoS attacks-GoldenEye', 'DoS attacks-Hulk', 'DoS attacks-SlowHTTPTest', 'DoS attacks-Slowloris', 'FTP-BruteForce', 'Infilteration', 'SQL Injection', 'SSH-Bruteforce']

# %% [markdown]
# # GLOBAL CLASS DISTRIBUTION (TRAIN)

# %%
global_counts = Counter(y_train.tolist())

print("Global Class Distribution (encoded labels):")
for cls_idx, cnt in sorted(global_counts.items()):
    print(f"{cls_idx} - {class_names[cls_idx]} : {cnt}")

plt.figure(figsize=(14, 4))
plt.bar(
    [str(k) for k in global_counts.keys()],
    list(global_counts.values())
)
plt.title("Global Class Distribution — CSE_CIC_IDS2018 (Train Split)")
plt.xlabel("Class Index")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Global Class Distribution (encoded labels):
# 0 - Benign : 4813839
# 1 - Bot : 200334
# 2 - Brute Force -Web : 428
# 3 - Brute Force -XSS : 161
# 4 - DDOS attack-HOIC : 480208
# 5 - DDOS attack-LOIC-UDP : 1211
# 6 - DDoS attacks-LOIC-HTTP : 403334
# 7 - DoS attacks-GoldenEye : 29055
# 8 - DoS attacks-Hulk : 323338
# 9 - DoS attacks-SlowHTTPTest : 97923
# 10 - DoS attacks-Slowloris : 7693
# 11 - FTP-BruteForce : 135352
# 12 - Infilteration : 113354
# 13 - SQL Injection : 61
# 14 - SSH-Bruteforce : 131312

# %% [markdown]
# # Dirichlet Non-IID Partitioning

# %%
def dirichlet_partition(y, n_clients, alpha, seed=42):
    np.random.seed(seed)
    random.seed(seed)

    all_indices = np.arange(len(y))
    unique_classes = sorted(list(set(y)))

    # Map each class → its indices
    class_to_indices = {
        c: all_indices[y == c] for c in unique_classes
    }
    for c in class_to_indices:
        np.random.shuffle(class_to_indices[c])

    client_samples = [[] for _ in range(n_clients)]

    # For each class, split its samples across clients according to Dirichlet
    for cls, idxs in class_to_indices.items():
        n = len(idxs)
        if n == 0:
            continue

        # Dirichlet proportions for this class
        proportions = np.random.dirichlet([alpha] * n_clients)

        # Convert proportions to integer sample counts
        counts = (proportions * n).astype(int)
        diff = n - counts.sum()
        # Fix rounding leftovers
        for _ in range(diff):
            j = np.random.randint(0, n_clients)
            counts[j] += 1

        start = 0
        for client_id in range(n_clients):
            c_count = counts[client_id]
            if c_count > 0:
                client_samples[client_id].extend(
                    idxs[start:start + c_count]
                )
                start += c_count

    # Shuffle indices inside each client
    for cid in range(n_clients):
        arr = np.array(client_samples[cid])
        np.random.shuffle(arr)
        client_samples[cid] = arr

    return client_samples

# %% [markdown]
# # PARTITION INTO NON-IID CLIENTS

# %%
client_indices = dirichlet_partition(
    y=y_train,
    n_clients=N_CLIENTS,
    alpha=DIRICHLET_ALPHA,
    seed=42
)

total_assigned = sum(len(idx) for idx in client_indices)
print("Total assigned samples :", total_assigned)
print("Original train samples :", len(y_train))
assert total_assigned == len(y_train), "Mismatch in sample counts!"
# Out:
# Total assigned samples : 6737603
# Original train samples : 6737603

# %% [markdown]
# # INSPECT CLIENT DISTRIBUTIONS

# %%
def class_distribution(indices):
    sub_labels = y_train[indices]
    c = Counter(sub_labels.tolist())
    return {int(k): int(v) for k, v in sorted(c.items())}

client_stats = []

for cid, idxs in enumerate(client_indices):
    dist = class_distribution(idxs)
    num_samples = len(idxs)
    num_classes_in_client = len(dist)

    # Top-3 most frequent classes in this client
    top3 = sorted(dist.items(), key=lambda x: x[1], reverse=True)[:3]
    top3_readable = [
        f"{cls_idx}({class_names[cls_idx]}):{cnt}" for cls_idx, cnt in top3
    ]

    client_stats.append({
        "client_id": cid,
        "num_samples": num_samples,
        "num_classes": num_classes_in_client,
        "class_distribution": dist,
        "top_classes": top3_readable
    })

for s in client_stats:
    print(f"\nClient {s['client_id']}:")
    print("  Samples     :", s["num_samples"])
    print("  #Classes    :", s["num_classes"])
    print("  Top Classes :", ", ".join(s["top_classes"]))
# Out:
# Client 0:
#   Samples     : 411443
#   #Classes    : 12
#   Top Classes : 0(Benign):394069, 8(DoS attacks-Hulk):9590, 4(DDOS attack-HOIC):5343
#
# Client 1:
#   Samples     : 590911
#   #Classes    : 15
#   Top Classes : 0(Benign):437606, 4(DDOS attack-HOIC):81357, 1(Bot):40178
#
# Client 2:
#   Samples     : 144530
#   #Classes    : 14
#   Top Classes : 6(DDoS attacks-LOIC-HTTP):96401, 0(Benign):18733, 1(Bot):11986
#
# Client 3:
#   Samples     : 618176
#   #Classes    : 13
#   Top Classes : 0(Benign):476583, 4(DDOS attack-HOIC):133274, 1(Bot):3782
#
# Client 4:
#   Samples     : 958220
#   #Classes    : 15
#   Top Classes : 0(Benign):838477, 4(DDOS attack-HOIC):37474, 7(DoS attacks-GoldenEye):19220
#
# Client 5:
#   Samples     : 385515
#   #Classes    : 14
#   Top Classes : 0(Benign):286091, 4(DDOS attack-HOIC):30312, 8(DoS attacks-Hulk):27586
#
# Client 6:
#   Samples     : 1045478
#   #Classes    : 14
#   Top Classes : 0(Benign):798072, 6(DDoS attacks-LOIC-HTTP):130461, 4(DDOS attack-HOIC):104012
#
# Client 7:
#   Samples     : 90598
#   #Classes    : 14
#   Top Classes : 14(SSH-Bruteforce):33475, 8(DoS attacks-Hulk):25942, 12(Infilteration):21139
#
# Client 8:
#   Samples     : 164841
#   #Classes    : 12
#   Top Classes : 0(Benign):78517, 6(DDoS attacks-LOIC-HTTP):49054, 12(Infilteration):10153
#
# Client 9:
#   Samples     : 81046
#   #Classes    : 14
#   Top Classes : 8(DoS attacks-Hulk):44438, 14(SSH-Bruteforce):12517, 1(Bot):11144
#
# Client 10:
#   Samples     : 78548
#   #Classes    : 13
#   Top Classes : 11(FTP-BruteForce):44820, 12(Infilteration):18074, 0(Benign):8613
#
# Client 11:
#   Samples     : 14574
#   #Classes    : 14
#   Top Classes : 1(Bot):4956, 8(DoS attacks-Hulk):3379, 9(DoS attacks-SlowHTTPTest):2636
#
# Client 12:
#   Samples     : 150155
#   #Classes    : 14
#   Top Classes : 0(Benign):55544, 9(DoS attacks-SlowHTTPTest):26062, 14(SSH-Bruteforce):25368
#
# Client 13:
#   Samples     : 443975
#   #Classes    : 14
#   Top Classes : 0(Benign):333300, 8(DoS attacks-Hulk):88926, 11(FTP-BruteForce):10130
#
# Client 14:
#   Samples     : 122264
#   #Classes    : 13
#   Top Classes : 0(Benign):79969, 6(DDoS attacks-LOIC-HTTP):28970, 11(FTP-BruteForce):6699
#
# Client 15:
#   Samples     : 58883
#   #Classes    : 14
#   Top Classes : 1(Bot):27373, 6(DDoS attacks-LOIC-HTTP):18320, 4(DDOS attack-HOIC):4226
#
# Client 16:
#   Samples     : 112681
#   #Classes    : 15
#   Top Classes : 8(DoS attacks-Hulk):84042, 4(DDOS attack-HOIC):16155, 11(FTP-BruteForce):3734
#
# Client 17:
#   Samples     : 61696
#   #Classes    : 14
#   Top Classes : 11(FTP-BruteForce):23147, 14(SSH-Bruteforce):18229, 8(DoS attacks-Hulk):14134
#
# Client 18:
#   Samples     : 1099602
#   #Classes    : 13
#   Top Classes : 0(Benign):1002595, 4(DDOS attack-HOIC):53795, 9(DoS attacks-SlowHTTPTest):20710
#
# Client 19:
#   Samples     : 104467
#   #Classes    : 13
#   Top Classes : 1(Bot):39571, 6(DDoS attacks-LOIC-HTTP):28633, 12(Infilteration):14793

# %%
sizes = [s["num_samples"] for s in client_stats]

plt.figure(figsize=(10, 4))
plt.bar(range(N_CLIENTS), sizes)
plt.title("Client-wise Sample Counts (Non-IID) — CSE_CIC_IDS2018")
plt.xlabel("Client ID")
plt.ylabel("Number of Samples")
plt.xticks(range(N_CLIENTS))
plt.tight_layout()
plt.show()

# %% [markdown]
# # SAVE CLIENT DATA (X.npy / y.npy) PER CLIENT

# %%
for cid, idxs in enumerate(client_indices):
    client_folder = os.path.join(CLIENTS_DIR, f"client_{cid}")
    os.makedirs(client_folder, exist_ok=True)

    Xc = X_train[idxs]
    yc = y_train[idxs]

    np.save(os.path.join(client_folder, "X.npy"), Xc)
    np.save(os.path.join(client_folder, "y.npy"), yc)

print("✔ Saved all client datasets under:", CLIENTS_DIR)
# Out:
# ✔ Saved all client datasets under: /users/

# %% [markdown]
# # Save Metadata JSON

# %%
metadata = {
    "dataset_name": DATASET_NAME,
    "generated_at": datetime.now().isoformat(),
    "n_clients": N_CLIENTS,
    "dirichlet_alpha": DIRICHLET_ALPHA,
    "global": {
        "num_samples": int(len(y_train)),
        "num_classes": int(num_classes),
        "class_index_to_name": {int(i): str(name) for i, name in enumerate(class_names)},
        "class_distribution": {int(k): int(v) for k, v in sorted(global_counts.items())},
    },
    "clients": [],
}

for s in client_stats:
    cid = s["client_id"]
    metadata["clients"].append({
        "client_id": cid,
        "num_samples": int(s["num_samples"]),
        "num_classes": int(s["num_classes"]),
        "class_distribution": {int(k): int(v) for k, v in s["class_distribution"].items()},
        "top_classes": s["top_classes"],
    })

meta_path = os.path.join(CLIENTS_DIR, "clients_metadata.json")
with open(meta_path, "w") as f:
    json.dump(metadata, f, indent=4)

print("✔ Metadata JSON saved to:", meta_path)
# Out:
# ✔ Metadata JSON saved to: /users/

# %%
doc = Document()
doc.add_heading(f"Client Partition Summary — {DATASET_NAME}", level=1)

doc.add_paragraph(f"Generated at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
doc.add_paragraph(f"Number of clients: {N_CLIENTS}")
doc.add_paragraph(f"Dirichlet alpha (Non-IID strength): {DIRICHLET_ALPHA}")
doc.add_paragraph(f"Total train samples: {len(y_train)}")
doc.add_paragraph(f"Number of classes: {num_classes}")

doc.add_heading("Global Class Distribution", level=2)
for cls_idx, cnt in sorted(global_counts.items()):
    doc.add_paragraph(
        f"{cls_idx} ({class_names[cls_idx]}): {cnt}",
        style="List Bullet"
    )

doc.add_heading("Client-wise Summary", level=2)
table = doc.add_table(rows=1, cols=5)
hdr = table.rows[0].cells
hdr[0].text = "Client ID"
hdr[1].text = "#Samples"
hdr[2].text = "#Classes"
hdr[3].text = "Top 3 Classes"
hdr[4].text = "Class Dist (truncated)"

for s in client_stats:
    row = table.add_row().cells
    row[0].text = str(s["client_id"])
    row[1].text = str(s["num_samples"])
    row[2].text = str(s["num_classes"])
    row[3].text = ", ".join(s["top_classes"])

    dist_items = list(s["class_distribution"].items())
    dist_str = ", ".join(
        f"{cls}({class_names[cls]}):{cnt}" for cls, cnt in dist_items[:5]
    )
    if len(dist_items) > 5:
        dist_str += " ..."
    row[4].text = dist_str

docx_path = os.path.join(CLIENTS_DIR, "clients_metadata_summary.docx")
doc.save(docx_path)

print("✔ DOCX summary saved to:", docx_path)
# Out:
# ✔ DOCX summary saved to: /users/
